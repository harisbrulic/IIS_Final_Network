# %%
import great_expectations as gx

context = gx.get_context()

try:
    context.delete_datasource("cyber_data")
except:
    pass

datasource = context.sources.add_pandas_filesystem(
    name="cyber_data",
    base_directory="../data"
)

normal_asset = datasource.add_csv_asset(
    name="normal_data",
    batching_regex=r"preprocessed\\normal\.csv"
)

attacks_asset = datasource.add_csv_asset(
    name="attacks_data",
    batching_regex=r"preprocessed\\attacks\.csv"
)

threats_asset = datasource.add_csv_asset(
    name="threats_data",
    batching_regex=r"preprocessed\\threats\.csv"
)

print("Done")
# Out:
# Done

# %%
for asset_name, suite_name, checkpoint_name in [
    ("normal_data", "normal_suite", "normal_checkpoint"),
    ("attacks_data", "attacks_suite", "attacks_checkpoint"),
    ("threats_data", "threats_suite", "threats_checkpoint"),
]:
    asset = context.get_datasource("cyber_data").get_asset(asset_name)
    
    suite = context.add_or_update_expectation_suite(
        expectation_suite_name=suite_name
    )
    
    batch_request = asset.build_batch_request()
    validator = context.get_validator(
        batch_request=batch_request,
        expectation_suite_name=suite_name
    )
    
    result = context.assistants.onboarding.run(
        validator=validator,
        exclude_column_names=[]
    )
    
    context.save_expectation_suite(
        expectation_suite=result.get_expectation_suite(),
        expectation_suite_name=suite_name
    )
    
    checkpoint = context.add_or_update_checkpoint(
        name=checkpoint_name,
        validations=[{
            "batch_request": batch_request,
            "expectation_suite_name": suite_name
        }]
    )
    
    checkpoint.run()
    print(f"✅ {suite_name} gotov!")

context.build_data_docs()
context.open_data_docs()
# Out:
# ...
# Calculating Metrics:   0%|          | 0/853 [00:00<?, ?it/s]
# ✅ normal_suite gotov!
# ...
# Calculating Metrics:   0%|          | 0/5 [00:00<?, ?it/s]
# ...
# ...
# Calculating Metrics:   0%|          | 0/741 [00:00<?, ?it/s]
# ✅ attacks_suite gotov!
# ...
# Calculating Metrics:   0%|          | 0/127 [00:00<?, ?it/s]
# ✅ threats_suite gotov!
